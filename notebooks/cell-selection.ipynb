# %%
from vitessce import *

# %%
spraggins_config = {
        "version": "0.1.0",
        "description": "High Bit Depth (uint16) Multiplex Immunofluorescence Imaging",
        "layers": [
        {
            "name": "raster",
            "type": "RASTER",
            "fileType": "raster.json",
            "url": "https://s3.amazonaws.com/vitessce-data/0.0.31/master_release/spraggins/spraggins.raster.json"
        }
        ],
        "name": "Spraggins",
        "public": True,
        "staticLayout": [
        {
            "component": "spatial",
            "props": {
            "view": {
                "zoom": -6.5,
                "target": [
                20000,
                20000,
                0
                ]
            }
            },
            "x": 0,
            "y": 0,
            "w": 9,
            "h": 2
        },
        {
            "component": "layerController",
            "x": 9,
            "y": 0,
            "w": 3,
            "h": 2
        }
        ]
}
dries_config = {
    "version": "0.1.0",
  "description": "Giotto, a pipeline for integrative analysis and visualization of single-cell spatial transcriptomic data",
  "layers": [
    {
      "name": "cells",
      "type": "CELLS",
      "fileType": "cells.json",
      "url": "https://s3.amazonaws.com/vitessce-data/0.0.31/master_release/dries/dries.cells.json"
    },
    {
      "name": "cell-sets",
      "type": "CELL-SETS",
      "fileType": "cell-sets.json",
      "url": "https://s3.amazonaws.com/vitessce-data/0.0.31/master_release/dries/dries.cell-sets.json"
    }
  ],
  "name": "Dries",
  "public": True,
  "staticLayout": [
    {
      "component": "description",
      "props": {
        "description": "Giotto, a pipeline for integrative analysis and visualization of single-cell spatial transcriptomic data"
      },
      "x": 9,
      "y": 0,
      "w": 3,
      "h": 2
    },
    {
      "component": "status",
      "x": 9,
      "y": 2,
      "w": 3,
      "h": 2
    },
    {
      "component": "cellSets",
      "x": 9,
      "y": 4,
      "w": 3,
      "h": 4
    },
    {
      "component": "cellSetSizes",
      "x": 5,
      "y": 4,
      "w": 4,
      "h": 4
    },
    {
      "component": "scatterplot",
      "props": {
        "mapping": "t-SNE",
        "view": {
          "zoom": 3,
          "target": [
            0,
            0,
            0
          ]
        }
      },
      "x": 0,
      "y": 2,
      "w": 5,
      "h": 4
    },
    {
      "component": "spatial",
      "props": {
        "cellRadius": 50,
        "view": {
          "zoom": -4.4,
          "target": [
            3800,
            -900,
            0
          ]
        }
      },
      "x": 5,
      "y": 0,
      "w": 4,
      "h": 4
    },
    {
      "component": "scatterplot",
      "props": {
        "mapping": "UMAP",
        "view": {
          "zoom": 3,
          "target": [
            0,
            0,
            0
          ]
        }
      },
      "x": 0,
      "y": 0,
      "w": 5,
      "h": 4
    }
  ]
}

# %%
w = VitessceWidget(config=dries_config)
w
# Out:
# VitessceWidget(config={'version': '0.1.0', 'description': 'Giotto, a pipeline for integrative analysis and vis…
# Running on 127.0.0.1:8000 over http (CTRL + C to quit)

# %%
w.config
# Out:
# {'version': '1.0.0',
#  'name': 'Dries',
#  'description': 'Giotto, a pipeline for integrative analysis and visualization of single-cell spatial transcriptomic data',
#  'public': True,
#  'datasets': [{'uid': 'A',
#    'name': 'A',
#    'files': [{'type': 'cells',
#      'fileType': 'cells.json',
#      'url': 'https://s3.amazonaws.com/vitessce-data/0.0.31/master_release/dries/dries.cells.json'},
#     {'type': 'cell-sets',
#      'fileType': 'cell-sets.json',
#      'url': 'https://s3.amazonaws.com/vitessce-data/0.0.31/master_release/dries/dries.cell-sets.json'}]}],
#  'initStrategy': 'auto',
#  'coordinationSpace': {'embeddingType': {'t-SNE': 't-SNE', 'UMAP': 'UMAP'},
#   'embeddingZoom': {'A': 3, 'B': 1.550623690962047},
#   'embeddingTargetX': {'A': 0, 'B': 7.245397246564636},
#   'embeddingTargetY': {'A': 0, 'B': -0.07089242682345542},
#   'spatialZoom': {'A': -4.4},
#   'spatialTargetX': {'A': 3800},
#   'spatialTargetY': {'A': -900},
#   'dataset': {'A': 'A'},
#   'embeddingRotation': {'A': 0},
#   'embeddingTargetZ': {'A': 0, 'B': -3.126388037344441e-13},
#   'spatialRotation': {'A': 0},
#   'spatialTargetZ': {'A': 0},
#   'cellFilter': {},
#   'cellSelection': {},
#   'cellHighlight': {'A': None},
#   'cellSetSelection': {'A': [['Leiden Clustering', 'Cluster 1'],
#     ['Leiden Clustering', 'Cluster 2'],
#     ['Leiden Clustering', 'Cluster 3'],
#     ['Leiden Clustering', 'Cluster 4'],
#     ['Leiden Clustering', 'Cluster 5'],
#     ['Leiden Clustering', 'Cluster 6'],
#     ['Leiden Clustering', 'Cluster 7'],
#     ['Leiden Clustering', 'Cluster 8'],
#     ['Leiden Clustering', 'Cluster 9']]},
#   'cellSetHighlight': {},
#   'geneSelection': {},
#   'geneHighlight': {},
#   'geneExpressionColormap': {'A': 'plasma'},
#   'geneExpressionColormapRange': {'A': [0, 1]},
#   'cellColorEncoding': {'A': 'cellSetSelection'},
#   'spatialLayers': {'A': [{'type': 'cells',
#      'opacity': 1,
#      'radius': 50,
#      'visible': True,
#      'stroked': False}]}},
#  'layout': [{'component': 'description',
#    'props': {'description': 'Giotto, a pipeline for integrative analysis and visualization of single-cell spatial transcriptomic data'},
#    'x': 9,
#    'y': 0,
#    'w': 3,
#    'h': 2,
#    'coordinationScopes': {'dataset': 'A', 'spatialLayers': 'A'}},
#   {'component': 'status',
#    'x': 9,
#    'y': 2,
#    'w': 3,
#    'h': 2,
#    'coordinationScopes': {'dataset': 'A',
#     'cellHighlight': 'A',
#     'cellSetHighlight': 'A',
#     'geneHighlight': 'A'}},
#   {'component': 'cellSets',
#    'x': 9,
#    'y': 4,
#    'w': 3,
#    'h': 4,
#    'coordinationScopes': {'dataset': 'A',
#     'cellFilter': 'A',
#     'cellSelection': 'A',
#     'cellSetSelection': 'A',
#     'cellSetHighlight': 'A',
#     'cellColorEncoding': 'A'}},
#   {'component': 'cellSetSizes',
#    'x': 5,
#    'y': 4,
#    'w': 4,
#    'h': 4,
#    'coordinationScopes': {'dataset': 'A',
#     'cellSetSelection': 'A',
#     'cellSetHighlight': 'A'}},
#   {'component': 'scatterplot',
#    'props': {'mapping': 't-SNE', 'view': {'zoom': 3, 'target': [0, 0, 0]}},
#    'x': 0,
#    'y': 2,
#    'w': 5,
#    'h': 4,
#    'coordinationScopes': {'embeddingType': 't-SNE',
#     'embeddingZoom': 'A',
#     'embeddingTargetX': 'A',
#     'embeddingTargetY': 'A',
#     'dataset': 'A',
#     'embeddingRotation': 'A',
#     'embeddingTargetZ': 'A',
#     'cellFilter': 'A',
#     'cellSelection': 'A',
#     'cellHighlight': 'A',
#     'cellSetSelection': 'A',
#     'cellSetHighlight': 'A',
#     'geneSelection': 'A',
#     'geneHighlight': 'A',
#     'geneExpressionColormap': 'A',
#     'geneExpressionColormapRange': 'A',
#     'cellColorEncoding': 'A'}},
#   {'component': 'spatial',
#    'props': {'cellRadius': 50,
#     'view': {'zoom': -4.4, 'target': [3800, -900, 0]}},
#    'x': 5,
#    'y': 0,
#    'w': 4,
#    'h': 4,
#    'coordinationScopes': {'spatialZoom': 'A',
#     'spatialTargetX': 'A',
#     'spatialTargetY': 'A',
#     'dataset': 'A',
#     'spatialRotation': 'A',
#     'spatialTargetZ': 'A',
#     'cellFilter': 'A',
#     'cellSelection': 'A',
#     'cellHighlight': 'A',
#     'cellSetSelection': 'A',
#     'cellSetHighlight': 'A',
#     'geneSelection': 'A',
#     'geneHighlight': 'A',
#     'geneExpressionColormap': 'A',
#     'geneExpressionColormapRange': 'A',
#     'cellColorEncoding': 'A',
#     'spatialLayers': 'A'}},
#   {'component': 'scatterplot',
#    'props': {'mapping': 'UMAP', 'view': {'zoom': 3, 'target': [0, 0, 0]}},
#    'x': 0,
#    'y': 0,
#    'w': 5,
#    'h': 4,
#    'coordinationScopes': {'embeddingType': 'UMAP',
#     'embeddingZoom': 'B',
#     'embeddingTargetX': 'B',
#     'embeddingTargetY': 'B',
#     'dataset': 'A',
#     'embeddingRotation': 'A',
#     'embeddingTargetZ': 'B',
#     'cellFilter': 'A',
#     'cellSelection': 'A',
#     'cellHighlight': 'A',
#     'cellSetSelection': 'A',
#     'cellSetHighlight': 'A',
#     'geneSelection': 'A',
#     'geneHighlight': 'A',
#     'geneExpressionColormap': 'A',
#     'geneExpressionColormapRange': 'A',
#     'cellColorEncoding': 'A'}}]}

# %%
w.config['coordinationSpace']['spatialZoom']['A']

# %%
w.config['coordinationSpace']['spatialLayers']['A'][0]['channels'][0]['slider']

# %%
w.config['coordinationSpace']['spatialLayers']['A'][0]['channels'][0]['visible']

# %%
w.config['coordinationSpace']['spatialLayers']['A'][0]['channels'][1]['visible']

# %%
w.get_cell_selection()
# Out:
# ['cell_172']
