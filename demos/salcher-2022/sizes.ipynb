# %%
import pandas as pd

# %%
import altair as alt

# %%
init_df = pd.read_csv("./o2_sizes.txt", sep="    ", header=None)
# Out:
# /var/folders/36/83j6x3ln225bvbpk1_vdzrm00000gn/T/ipykernel_22610/1135000281.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   init_df = pd.read_csv("./o2_sizes.txt", sep="    ", header=None)

# %%
df = init_df.rename(columns={ 0: "size", 1: "size_human", 2: "filename" })

df["num_cells"] = [1000000, 1000000, 100000, 100000, 10000, 10000, 1000, 1000, 100, 100, 10, 10]
df["num_values"] = df["num_cells"] * 17811
df["format"] = ["csv", "zarr"] * 6
df["size_offset_y"] = [-3000000, 0, 0, 0, 3000000, 500000, 3000000, 500000, 3000000, 500000, 3000000, 500000]
df["size_offset_x"] = [0, 0, 0, 0, 0, 0, 1000, 1000, 100, 100, 30, 30]

df["text_x"] = df["num_cells"] + df["size_offset_x"]
df["text_y"] = df["size"] + df["size_offset_y"]

# %%
df
# Out:
#         size size_human                    filename  num_cells   num_values  \
# 0   79098107        76G    ./small_1000000.csvs_dir    1000000  17811000000
# 1   15340216        15G   ./small_1000000.h5ad.zarr    1000000  17811000000
# 2    8036644       7.7G     ./small_100000.csvs_dir     100000   1781100000
# 3    1759209       1.7G    ./small_100000.h5ad.zarr     100000   1781100000
# 4     820039       801M      ./small_10000.csvs_dir      10000    178110000
# 5     202199       198M     ./small_10000.h5ad.zarr      10000    178110000
# 6      82244        81M       ./small_1000.csvs_dir       1000     17811000
# 7      18991        19M      ./small_1000.h5ad.zarr       1000     17811000
# 8       9918       9.7M        ./small_100.csvs_dir        100      1781100
# 9       3294       3.3M       ./small_100.h5ad.zarr        100      1781100
# 10      2784       2.8M         ./small_10.csvs_dir         10       178110
# 11      1892       1.9M        ./small_10.h5ad.zarr         10       178110
#
#    format  size_offset_y  size_offset_x   text_x    text_y
# 0     csv       -3000000              0  1000000  76098107
# 1    zarr              0              0  1000000  15340216
# 2     csv              0              0   100000   8036644
# 3    zarr              0              0   100000   1759209
# 4     csv        3000000              0    10000   3820039
# 5    zarr         500000              0    10000    702199
# 6     csv        3000000           1000     2000   3082244
# 7    zarr         500000           1000     2000    518991
# 8     csv        3000000            100      200   3009918
# 9    zarr         500000            100      200    503294
# 10    csv        3000000             30       40   3002784
# 11   zarr         500000             30       40    501892

# %%
points = alt.Chart(df).mark_line(point=True).encode(
    x=alt.X("num_cells:Q").scale(type="log").title("Number of cells"),
    y=alt.Y("size:Q").title("Total data size (bytes)"),
    color=alt.Color("format:N").title("Format"),
    shape=alt.Shape("format:N").title("Format"),
    text="size_human:N"
)


text = alt.Chart(df).mark_text(dx = -20, dy=-5).encode(
    x=alt.X("text_x:Q").scale(type="log"),
    y=alt.Y("text_y:Q"),
    color="format:N",
    text="size_human:N"
)


(points + text).properties(title="CSV vs. Zarr file size comparisons")
# Out:
# alt.LayerChart(...)
